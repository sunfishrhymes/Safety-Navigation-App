# %%
import pandas as pd

# %%
map = pd.read_csv('CMPD_Incidents.csv')
# Out:
# /tmp/ipykernel_603/326344030.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   map = pd.read_csv('CMPD_Incidents.csv')

# %%
roads = map[(map['CITY'] == 'CHARLOTTE') & (map['PLACE_DETAIL_DESCRIPTION'] == 'Street/Highway')]['LOCATION']

# %%
roads.to_csv('DangerousRoads.csv', index=False)
